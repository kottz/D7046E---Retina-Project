# %%
# Enable inline plots in the notebook
# %matplotlib inline

# Import library functions needed
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import MaxNLocator
import json


# Set default figure size
plt.rcParams['figure.figsize'] = [6,6]

# Function that is used to plot spike times
def rasterplot(ax, x, y, x_label, y_label):
    ax.set_xlabel(x_label)
    ax.set_ylabel(y_label)
    ax.scatter(x, y, marker='|')
    ax.yaxis.set_major_locator(MaxNLocator(integer=True))

# %%
####################################################################################################
# Simulation parameters
dt = 1e-4                    # Timestep
t = np.arange(0,30000)*dt    # Simulation time array t
num_receptors = 5           # Number of receptor neurons
speed = 20                   # Speed of bright spot, number of receptor neurons passed per second
####################################################################################################

plot_t = []                  # Time of spikes
plot_n = []                  # Receptor neuron id's
currtime = 0                 # Time when a spike is fired
neuronid = 0                 # Neuron that fires a spike
stepdir = 1                  # Is the bright spot moving towards the right (1) or left (-1)
timestep = 1.0/(speed-1)     # Time between spikes generated by nearby receptor neurons

# Make placeholders for spike time arrays to be used for SNN simulation
spikes = []
for i in range(num_receptors):
    spikes.append([])

# Generate and plot spikes from receptor neurons
while currtime < t[-1]:
    plot_t.append(currtime)
    plot_n.append(neuronid)
    spikes[neuronid].append(currtime)
    if neuronid == 0 and stepdir == -1:
        stepdir = 1
    elif neuronid == (num_receptors-1) and stepdir == 1:
        stepdir = -1
    neuronid += stepdir
    currtime += timestep
    
# Plot spikes
fig, ax = plt.subplots()
rasterplot(ax, plot_t, plot_n,'Time [s]','Receptor neuron ID')
ax.grid()

# %%
data = [[0, 0.033333, 0.066666, 0.099999, 0.133332, 0.166665], [0.033333, 0.066666, 0.099999, 0.133332, 0.166665, 0.199998], [0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331], [0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664], [0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333], [0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996], [0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329], [0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662], [0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995], [0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328], [0.33333, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001], [0.366663, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001], [0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002], [0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003], [0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004], [0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004], [0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004], [0.6666600000000003, 0.6999930000000003, 0.7333260000000004, 0.7666590000000004], [0.6999930000000003, 0.7333260000000004, 0.7666590000000004, 0.7999920000000005], [0.6999930000000003, 0.7333260000000004, 0.7666590000000004, 0.7999920000000005, 0.8333250000000005], [0.7333260000000004, 0.7666590000000004, 0.7999920000000005, 0.8333250000000005, 0.8666580000000006], [0.7333260000000004, 0.7666590000000004, 0.7999920000000005, 0.8333250000000005, 0.8666580000000006, 0.8999910000000007], [0.7666590000000004, 0.7999920000000005, 0.8333250000000005, 0.8666580000000006, 0.8999910000000007, 0.9333240000000007, 0.9999900000000008], [0.7999920000000005, 0.8333250000000005, 0.8666580000000006, 0.8999910000000007, 0.9333240000000007, 0.9666570000000008, 0.9999900000000008, 1.0333230000000009], [0.8333250000000005, 0.8666580000000006, 0.8999910000000007, 0.9333240000000007, 0.9666570000000008, 0.9999900000000008, 1.0333230000000009], [0.8666580000000006, 0.8999910000000007, 0.9333240000000007, 0.9666570000000008, 0.9999900000000008, 1.0333230000000009, 1.099989000000001], [0.8999910000000007, 0.9333240000000007, 0.9666570000000008, 0.9999900000000008, 1.0333230000000009, 1.066656000000001, 1.099989000000001, 1.133322000000001], [0.9333240000000007, 0.9999900000000008, 1.0333230000000009, 1.066656000000001, 1.099989000000001, 1.133322000000001, 1.166655000000001], [1.0333230000000009, 1.066656000000001, 1.099989000000001, 1.133322000000001, 1.166655000000001, 1.1999880000000012], [1.066656000000001, 1.099989000000001, 1.133322000000001, 1.166655000000001, 1.1999880000000012, 1.2333210000000012], [1.099989000000001, 1.133322000000001, 1.166655000000001, 1.1999880000000012, 1.2333210000000012, 1.2666540000000013], [1.133322000000001, 1.166655000000001, 1.1999880000000012, 1.2333210000000012, 1.2666540000000013, 1.2999870000000013], [1.166655000000001, 1.2333210000000012, 1.2666540000000013, 1.2999870000000013, 1.3333200000000014], [1.2666540000000013, 1.2999870000000013, 1.3333200000000014, 1.3666530000000014], [1.2999870000000013, 1.3333200000000014, 1.3666530000000014, 1.3999860000000015], [1.2999870000000013, 1.3333200000000014, 1.3666530000000014, 1.3999860000000015, 1.4333190000000016, 1.4999850000000017], [1.2999870000000013, 1.3333200000000014, 1.3666530000000014, 1.3999860000000015, 1.4333190000000016, 1.4666520000000016, 1.4999850000000017, 1.5333180000000017], [1.3333200000000014, 1.3999860000000015, 1.4333190000000016, 1.4666520000000016, 1.4999850000000017, 1.5333180000000017, 1.5666510000000018], [1.3666530000000014, 1.4333190000000016, 1.4666520000000016, 1.4999850000000017, 1.5333180000000017, 1.5666510000000018, 1.5999840000000018], [1.4666520000000016, 1.4999850000000017, 1.5333180000000017, 1.5666510000000018, 1.5999840000000018, 1.633317000000002], [1.4999850000000017, 1.5333180000000017, 1.5666510000000018, 1.5999840000000018, 1.633317000000002, 1.666650000000002], [1.5333180000000017, 1.5666510000000018, 1.5999840000000018, 1.633317000000002, 1.666650000000002, 1.699983000000002], [1.5666510000000018, 1.5999840000000018, 1.633317000000002, 1.666650000000002, 1.699983000000002, 1.733316000000002], [1.5999840000000018, 1.633317000000002, 1.666650000000002, 1.699983000000002, 1.733316000000002], [1.633317000000002, 1.666650000000002, 1.699983000000002, 1.733316000000002], [1.666650000000002, 1.699983000000002, 1.733316000000002, 1.7666490000000021], [1.699983000000002, 1.733316000000002, 1.7666490000000021, 1.7999820000000022], [1.733316000000002, 1.7666490000000021, 1.7999820000000022, 1.8333150000000022], [1.733316000000002, 1.7666490000000021, 1.7999820000000022, 1.8333150000000022, 1.8666480000000023], [1.733316000000002, 1.7666490000000021, 1.7999820000000022, 1.8333150000000022, 1.8666480000000023, 1.8999810000000024], [1.7666490000000021, 1.7999820000000022, 1.8333150000000022, 1.8666480000000023, 1.8999810000000024, 1.9333140000000024], [1.7999820000000022, 1.8333150000000022, 1.8666480000000023, 1.8999810000000024, 1.9333140000000024, 1.9666470000000025], [1.8333150000000022, 1.8666480000000023, 1.8999810000000024, 1.9333140000000024, 1.9666470000000025, 1.9999800000000025], [1.8666480000000023, 1.8999810000000024, 1.9333140000000024, 1.9666470000000025, 1.9999800000000025, 2.0333130000000024], [1.8999810000000024, 1.9333140000000024, 1.9666470000000025, 1.9999800000000025, 2.0333130000000024, 2.066646000000002], [1.9333140000000024, 1.9666470000000025, 1.9999800000000025, 2.0333130000000024, 2.066646000000002, 2.099979000000002], [1.9666470000000025, 1.9999800000000025, 2.0333130000000024, 2.066646000000002, 2.099979000000002, 2.133312000000002]]

# %%
data = [[0.6333270000000002, 0.6666600000000003, 0.6999930000000003], [0.6333270000000002, 0.6666600000000003], [0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.5999940000000001, 0.6333270000000002], [0.5666610000000001, 0.5999940000000001], [0.5666610000000001, 0.5999940000000001], [0.5666610000000001, 0.5999940000000001], [0.5666610000000001], [0.533328, 0.5666610000000001], [0.533328, 0.5666610000000001], [0.533328], [0.533328], [0.499995, 0.533328], [0.499995, 0.533328], [0.499995, 0.533328], [0.466662, 0.499995], [0.466662, 0.499995], [0.466662, 0.499995], [0.433329, 0.466662], [0.433329, 0.466662], [0.433329, 0.466662], [0.433329], [0.399996, 0.433329], [0.399996, 0.433329], [0.399996], [0.399996], [0.366663, 0.399996], [0.366663], [0.366663], [0.33333, 0.366663], [0.299997, 0.33333], [0.299997, 0.33333], [0.299997, 0.33333], [0.266664, 0.299997], [0.266664, 0.299997], [0.266664, 0.299997], [0.233331, 0.266664], [0.233331, 0.266664], [0.233331, 0.266664], [0.199998, 0.233331], [0.199998, 0.233331], [0.199998, 0.233331], [0.166
.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004, 0.7666590000000004, 0.7999920000000005], [0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004, 0.7666590000000004, 0.7999920000000005], [0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004, 0.7666590000000004, 0.7999920000000005], [0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004, 0.7666590000000004], [0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004, 0.7666590000000004], [0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004, 0.7666590000000004], [0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004], [0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004], [0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003, 0.7333260000000004], [0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003, 0.6999930000000003], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002, 0.6666600000000003], [0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001, 0.6333270000000002], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001], [0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001], [0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001, 0.5999940000000001], [0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001], [0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001], [0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328, 0.5666610000000001], [0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328], [0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328], [0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995, 0.533328], [0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995], [0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995], [0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662, 0.499995], [0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662], [0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662], [0.033333, 0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329, 0.466662], [0, 0.033333, 0.066666, 0.099999, 0.133332, 0.166665, 0.199998, 0.233331, 0.266664, 0.299997, 0.33333, 0.366663, 0.399996, 0.433329]]

# %%
f = open('data_file.json',)
data = json.load(f)

# %%
left_iter = iter([x['spikes'] for x in data['left']])
right_iter = iter([x['spikes'] for x in data['right']])

# %%
def lif_neuron(I_inject, E_L=-65e-3, u_reset=-65e-3, u_thres=-50e-3, R=90e6, tau_m=30e-3):
    # LIF neuron with a constant injection current
    return {
        'type'    : 'lif',
        'u'       : u_reset,                   # Membrane potential [Volt]
        'E_L'     : E_L,                       # Leakage resting potential [Volt]
        'u_reset' : u_reset,                   # Reset potential after spike [Volt]
        'u_thres' : u_thres,                   # Threshold for spike generation [Volt]
        'R'       : R,                         # Membrane resistance [Ohm]
        'tau_m'   : tau_m,                     # Membrane time constant [second]
        'I_inj'   : I_inject,                  # Injection current [Ampere]
    }

def lif_syn_neuron(num_synapses, E_L=-65e-3, u_reset=-65e-3, u_thres=-50e-3, R=90e6, tau_m=30e-3, I_inject=0, tau_syn=50e-3):
    # LIF neuron with dynamic synapses
    n = lif_neuron(I_inject, E_L, u_reset, u_thres, R, tau_m)
    n['tau_syn'] = tau_syn                     # Synapse time constant [second] (can also be an array)
    n['I_syn']   = np.zeros(num_synapses)      # Postsynaptic currents [Ampere]
    n['w_syn']   = np.zeros(num_synapses)      # Synaptic weights [Ampere]
    n['type']    = 'lif_syn'
    return n

def lif_stdp_neuron(num_synapses, E_L=-65e-3, u_reset=-65e-3, u_thres=-50e-3, R=90e6, tau_m=30e-3, I_inject=0,
                    tau_syn=50e-3, tau_pls=20e-3, tau_mns=20e-3, w_max=1e-9, w_min=1e-12, gamma=1):
    # LIF neuron with dynamic synapses and pair-based STDP
    n = lif_syn_neuron(num_synapses, E_L, u_reset, u_thres, R, tau_m, I_inject, tau_syn)
    n['x_pre']   = np.zeros(num_synapses)      # STDP trace of presynaptic spikes
    n['y_pst']   = 0                           # STDP trace of postsynaptic spikes (scalar, one neuron)
    n['tau_pls'] = tau_pls                     # STDP trace time constant [second] (can also be an array)
    n['tau_mns'] = tau_mns                     # STDP trace time constant [second] (can also be an array)
    n['w_max']   = w_max                       # Largest allowed value of synapse conductance
    n['w_min']   = w_min                       # Lowest allowed value of synapse conductance
    n['gamma']   = gamma                       # Learning rate parameter with soft bounds (w_min,w_max)
    n['type']    = 'lif_stdp'
    return n
          
def integrate(dt, t, neurons):
    # Integrate the membrane potential, postsynaptic currents etc one timestep dt
    for n in neurons:
        if n['type'] == 'lif':
            # Integrate membrane potential
            dudt = (n['E_L'] - n['u'] + n['R']*n['I_inj']) / n['tau_m']
            n['u'] += dt*dudt
        elif n['type'] in ['lif_syn','lif_stdp']:
            # Integrate array of postsynaptic currents, one current for each synapse
            didt = np.divide(-n['I_syn'], n['tau_syn'])
            n['I_syn'] += dt*didt
            # Integrate membrane potential
            dudt = (n['E_L'] - n['u'] + n['R']*(n['I_inj']+sum(n['I_syn']))) / n['tau_m']
            n['u'] += dt*dudt
            # Integrate local traces for pair-based plasticity
            if n['type'] == 'lif_stdp':
                n['x_pre'] -= dt*np.divide(n['x_pre'], n['tau_pls'])       # Eq 19.12
                n['y_pst'] -= dt*np.divide(n['y_pst'], n['tau_mns'])       # Eq 19.13

def spikegen(dt, t, neurons):
    # Implements the non-linear spike generation mechanism
    spikes = []
    for i,n in enumerate(neurons):
        if n['type'] in ['lif','lif_syn','lif_stdp']:
            if n['u'] > n['u_thres']:
                n['u'] = n['u_reset']
                spikes.append(i)
        elif n['type'] == 'poisson':
            if np.random.rand() < dt*n['frequency']:
                spikes.append(i)
        elif n['type'] == 'generator':
            j = np.searchsorted(n['spike_t'], t, side='right')
            if j>0 and t-n['spike_t'][j-1]<dt:
                spikes.append(i)            
    return spikes

def update(dt, t, neurons, connections):
    # Update the state of a spiking neural network.
    # Refer to Exercise 3 for a reminder about how to set up connections between neurons.
    integrate(dt, t, neurons)
    spikes = spikegen(dt, t, neurons)

    # Update weights and STDP trace for each postsynaptic spike
    for spike in spikes:
        n = neurons[spike]
        if n['type'] in ['lif_stdp']:
            n['y_pst'] += 1                                         # Eq 19.13
            for i,w in enumerate(n['w_syn']):
                if w > 0:                                           # Excitatory synapses
                    Aplus = n['gamma']*(n['w_max'] - n['w_syn'][i]) # Eq 19.4
                    n['w_syn'][i] += dt*Aplus*n['x_pre'][i]         # Eq 19.14
    
    # Update synapse currents, weights and STDP traces for each presynaptic spike
    for (post, syn, pre) in connections:
        for spike in spikes:
            if spike == pre:
                n = neurons[post]
                
                if n['type'] not in ['lif_syn', 'lif_stdp']:
                    print('Error: Spike sent to neuron type without synapses')
                
                # Update synapse currents
                if n['type'] in ['lif_syn','lif_stdp']:
                    n['I_syn'][syn] += n['w_syn'][syn]
                    
                # Update STDP trace and weight
                if n['type'] in ['lif_stdp']:
                    n['x_pre'][syn] += 1                                   # Eq 19.12
                    if n['w_syn'][syn] > 0:                                # Excitatory synapses
                        Aminus = n['gamma']*(n['w_min'] - n['w_syn'][syn]) # Eq 19.4
                        n['w_syn'][syn] += dt*Aminus*n['y_pst']            # Eq 19.14
    
    return spikes

# To simulate the spikes from the receptor neurons you will need an additional neuron constructor defined as

def spike_generator(spike_times):
    # Generates spikes at time points defined by the sorted list 'spike_t'
    return {
        'type'      : 'generator',
        'spike_t'   : spike_times              # Array of spike times, separated by at least dt
}


# With these modifications of the simulator code you should be able to simulate the receptor neurons using
# spike_generator neurons initialized with the spike time arrays produced by the data generator code above.

# The construction of neurons and configuration of synapses should be done in a similar way as in SNN Exercise 1.

# %%
nr_of_neurons = 60
neurons = []

#create list of neurons

for neuron in list(range(0,nr_of_neurons)):
    l1 = spike_generator(data['left'][0]['spikes'])
    neurons.append(l1)

for neuron in list(range(0,(nr_of_neurons-1))):
    l2 = lif_stdp_neuron(1,u_thres=-62e-3)
    l2['w_syn'][0] = 72e-12
    neurons.append(l2)

for neuron in list(range(0,(nr_of_neurons-1))):
    l3 = lif_stdp_neuron(2)
    l3['w_syn'][0] = -360e-12
    l3['w_syn'][1] = 360e-12
    neurons.append(l3)

left = lif_stdp_neuron(nr_of_neurons, w_min=0) #(nr_of_neurons-1)

for synapse in list(range(0,nr_of_neurons-1)):
    left['w_syn'][synapse] = 200e-12
    
neurons.append(left)
left_index = len(neurons)-1

for neuron in list(range(0,(nr_of_neurons-1))):
    l2 = lif_stdp_neuron(1,u_thres=-62e-3)
    l2['w_syn'][0] = 72e-12
    neurons.append(l2)
    
for neuron in list(range(0,(nr_of_neurons-1))):
    l3 = lif_stdp_neuron(2)
    l3['w_syn'][0] = -360e-12
    l3['w_syn'][1] = 360e-12
    neurons.append(l3)

right = lif_stdp_neuron(nr_of_neurons, w_min=0) #(nr_of_neurons-1)

for synapse in list(range(0,nr_of_neurons-1)):
    right['w_syn'][synapse] = 200e-12
    
neurons.append(right)
right_index = len(neurons)-1

right['w_syn'][nr_of_neurons-1] = -1e-12
left['w_syn'][nr_of_neurons-1] = -1e-12

#create connections

connections = []
for i in range(0,nr_of_neurons-1):
    
    #Left
    connections.append([nr_of_neurons+i,0,i])
    connections.append([nr_of_neurons*2-1+i,0,nr_of_neurons+i])
    connections.append([nr_of_neurons*2-1+i,1,1+i])
    connections.append([(nr_of_neurons-1)*3+1,i,nr_of_neurons*2-1+i])
    
    # Right
    connections.append([(nr_of_neurons-1)*3+2+i,0,1+i])
    connections.append([(nr_of_neurons-1)*4+2+i,0,(nr_of_neurons-1)*3+2+i])
    connections.append([(nr_of_neurons-1)*4+2+i,1,i])
    connections.append([(nr_of_neurons-1)*5+2,i,(nr_of_neurons-1)*4+2+i])
    
    connections.append([right_index,nr_of_neurons-1,left_index])
    connections.append([left_index,nr_of_neurons-1,right_index])

# %%
dt = 1e-3
t = 0
t0 = t
tv = []
u1 = []
u2 = []

t_spike = []
n_spike = []

while t < t0+0.5:

    print('\r{}'.format(t), end='')

    # Update the network
    spikes = update(dt, t, neurons, connections)
    
    # Store membrane potentials of n1 and n2 for plotting/analysis
    tv.append(t)
    u1.append(left['u'])
    u2.append(right['u'])
    
    # Store spikes needed for plotting/analysis
    if len(spikes)>0:
        for s in spikes:
            t_spike.append(t)
            n_spike.append(s)

    # Timestep completed
    t += dt
    
plt.rcParams['figure.figsize'] = [10, 10]
fig,(ax1,ax2,ax3) = plt.subplots(3,1, sharex=True)
ax1.plot(tv,u1); ax1.set_ylabel('u1(t)')
ax2.plot(tv,u2); ax2.set_ylabel('u2(t)')
rasterplot(ax3, t_spike, n_spike,'Time [s]','Neuron index')
# Out:
# 0
# C:\Users\Admin\anaconda3\envs\nnlm\lib\site-packages\numpy\core\_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-7-b5995aa15803> in <module>
#      14
#      15     # Update the network
# ---> 16     spikes = update(dt, t, neurons, connections)
#      17
#      18     # Store membrane potentials of n1 and n2 for plotting/analysis
#
# <ipython-input-5-380950c86ee5> in update(dt, t, neurons, connections)
#      75     # Refer to Exercise 3 for a reminder about how to set up connections between neurons.
# ...

# %%
left_spikes = 0
right_spikes = 0
for number in n_spike:
    if number == neurons.index(left):
        left_spikes += 1
    elif number == neurons.index(right):
        right_spikes += 1
print(left_spikes)
print(right_spikes)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-b72badc31c84> in <module>
#       1 left_spikes = 0
#       2 right_spikes = 0
# ----> 3 for number in n_spike:
#       4     if number == neurons.index(left):
#       5         left_spikes += 1
#
# NameError: name 'n_spike' is not defined

# %%
def plot_neuron_weights(n):
# Plot the input weights of an excitatory neuron (with STDP synapses)
    plt.rcParams['figure.figsize'] = [10, 10]
    fig,ax = plt.subplots()
    ax.hist(np.hstack(img))
    ax.set_xlabel('Weight [pA]')
    ax.set_ylabel('No. synapses')
    plt.show()
    
def plot_neuron_weights(n):
# Plot the input weights of an excitatory neuron (with STDP synapses)
    plt.rcParams['figure.figsize'] = [10, 3]
    fig,(ax1,ax2) = plt.subplots(1,2)
    rasterplot(ax1, t_spike, n_spike,'Time [s]','Neuron index')
    ax2.hist(np.hstack(img))
    ax2.set_xlabel('Weight [pA]')
    ax2.set_ylabel('No. synapses')
    plt.show()
    
def spike_input_time(spikes):
    i = 0
    while spikes[i] == []:
        i += 1
    
    latest_spike_left = spikes[i][-1]
    i = len(spikes)-1
    
    while spikes[i] == []:
        i -= 1
        
    latest_spike_right = spikes[i][-1]
    return max(latest_spike_left, latest_spike_right)

# %%
i = 0

# Reset the simulation time
t = 0
dt = 1e-3
rsttime = 0.5

# Speed up learning a bit
left['gamma'] = 5
right['gamma'] = 5

for iterations in range(10): # Training iterations
    
    t = 0
    
    tv = []
    u1 = []
    u2 = []

    t_spike = []
    n_spike = []
    
    # Start time
    t0 = t
    
    # Spike counts of e1 and e2
    left_count = 0
    right_count = 0
    
    
    # Sample a different digit every second iteration
    stimuli = []
    if iterations % 2 == 0:
        stimuli = next(right_iter)
        ##############################################################################
        # INSERT SUPERVISION SIGNAL HERE, INHIBIT ONE OF THE TWO STDP NEURONS
        left['w_syn'][nr_of_neurons-1] = -2e-12
        right['w_syn'][nr_of_neurons-1] = 0
        ##############################################################################
    else:
        stimuli = next(left_iter)
        ##############################################################################
        # INSERT SUPERVISION SIGNAL HERE, INHIBIT ONE OF THE TWO STDP NEURONS
        left['w_syn'][nr_of_neurons-1] = 0
        right['w_syn'][nr_of_neurons-1] = -2e-12
        ##############################################################################
    
    for neuron in list(range(0,nr_of_neurons)):
        l1 = spike_generator(stimuli[neuron])
        neurons[neuron] = l1
        
    
    simtime = spike_input_time(stimuli)
    
    # Simulate the network
    while t < t0+simtime:
        
        # Update network, including STDP
        spikes = update(dt, t, neurons, connections)
        
        # Store membrane potentials of n1 and n2 for plotting/analysis
        tv.append(t)
        u1.append(left['u'])
        u2.append(right['u'])
        
        # Store spikes needed for plotting/analysis
        if len(spikes)>0:
            for s in spikes:
                t_spike.append(t)
                n_spike.append(s)
        
        # Count number of spikes from e1 and e2
        left_count += spikes.count(left_index)
        right_count += spikes.count(right_index)
        
        # Timestep completed
        t += dt
        
        print('\r t = {}s, simtime = {}, iteration = {}'.format(str(t), str(simtime), str(i)), end='')

    i += 1
    # Let neurons and synapses rest before the next stimuli 
    
    while t < t0+simtime+rsttime:
        spikes = update(dt, t, neurons, connections)
        
        # Store membrane potentials of n1 and n2 for plotting/analysis
        tv.append(t)
        u1.append(left['u'])
        u2.append(right['u'])
        
        # Store spikes needed for plotting/analysis
        if len(spikes)>0:
            for s in spikes:
                t_spike.append(t)
                n_spike.append(s)
        
        left_count += spikes.count(left_index)
        right_count += spikes.count(right_index)
        t += dt
        print('\r t = {}s, simtime = {}, iteration = {}, rest'.format(str(t), str(simtime), str(i)), end='')
        
    print('\n -----')
    print(left_count, right_count)
    
    weights_right = neurons[right_index]['w_syn']
    nr_synapse = list(range(len(weights_right)))
    weights_left = neurons[left_index]['w_syn']
    
    plt.rcParams['figure.figsize'] = [10, 10]
    fig,(ax1,ax2,ax3) = plt.subplots(3,1, sharex=True)
    ax1.plot(tv,u1); ax1.set_ylabel('u1(t)')
    ax2.plot(tv,u2); ax2.set_ylabel('u2(t)')
    rasterplot(ax3, t_spike, n_spike,'Time [s]','Neuron index')
    plt.show()
    
    plt.rcParams['figure.figsize'] = [10, 10]
    fig,(ax1,ax2) = plt.subplots(2,1, sharex=True)
    ax1.bar(nr_synapse,weights_right); ax1.set_ylabel('w')
    ax2.bar(nr_synapse,weights_left); ax2.set_ylabel('w')
    plt.show()
# Out:
#  t = 1.5339999999999419s, simtime = 1.0332299999999994, iteration = 1, rest
#  -----
# 0 70
#  t = 1.5339999999999419s, simtime = 1.0332299999999994, iteration = 2, rest
#  -----
# 54 0
#  t = 1.1999999999999786s, simtime = 0.6999299999999996, iteration = 3, rest
#  -----
# 0 28
#  t = 1.1999999999999786s, simtime = 0.6999299999999996, iteration = 4, rest
#  -----
# 25 0
#  t = 1.0000000000000007s, simtime = 0.4999499999999998, iteration = 5, rest
#  -----
# 0 20
#  t = 1.0000000000000007s, simtime = 0.4999499999999998, iteration = 6, rest
#  -----
# 17 0
#  t = 2.8669999999997953s, simtime = 2.3664300000000003, iteration = 7, rest
#  -----
# 0 102
#  t = 2.8669999999997953s, simtime = 2.3664300000000003, iteration = 8, rest
#  -----
# 89 0
#  t = 1.5339999999999419s, simtime = 1.0332299999999994, iteration = 9, rest
#  -----
# 0 55
#  t = 1.5339999999999419s, simtime = 1.0332299999999994, iteration = 10, rest
#  -----
# 50 0

# %%
test_data = [[0.06666, 0.09999, 0.19998, 0.29996999999999996, 0.8999099999999994, 0.9998999999999993, 1.0665599999999995, 1.3998600000000003, 1.4665200000000005, 1.699830000000001, 1.9998000000000018, 2.1331200000000012, 2.233110000000001, 2.2664400000000007, 2.5997399999999993, 2.666399999999999, 2.699729999999999, 2.7330599999999987, 2.933039999999998, 2.9663699999999977, 2.9996999999999976, 3.166349999999997, 3.1996799999999967, 3.2663399999999965, 3.4663199999999956, 3.832949999999994, 3.866279999999994, 3.899609999999994, 3.9329399999999937, 3.9662699999999935, 3.9995999999999934, 4.032929999999993, 4.0662599999999935, 4.099589999999994, 4.132919999999994, 4.199579999999995, 4.266239999999995, 4.366229999999996, 4.399559999999997, 4.432889999999997, 4.466219999999997, 4.4995499999999975, 4.532879999999998, 4.566209999999998, 4.599539999999998, 4.632869999999999, 4.666199999999999, 4.699529999999999, 4.73286, 4.76619, 4.79952, 4.866180000000001, 4.899510000000001, 4.9328400000000014, 4.966170000000002, 4.999500000000002], [0.06666, 0.09999, 0.19998, 0.29996999999999996, 0.8999099999999994, 0.9998999999999993, 1.0665599999999995, 1.3998600000000003, 1.4665200000000005, 1.699830000000001, 1.9998000000000018, 2.1331200000000012, 2.233110000000001, 2.2664400000000007, 2
 2.39976, 2.43309, 2.46642, 2.4997499999999997, 2.5330799999999996, 2.5664099999999994, 2.699729999999999, 2.7997199999999984, 2.8330499999999983, 2.9663699999999977, 3.0330299999999975, 3.0663599999999973, 3.2663399999999965, 3.2996699999999963, 3.332999999999996, 3.366329999999996, 3.399659999999996], [0.13332, 0.16665, 0.19998, 0.26664, 0.39995999999999987, 0.5999399999999997, 0.6999299999999996, 1.0332299999999994, 1.1665499999999998, 1.3332000000000002, 1.3665300000000002, 1.4331900000000004, 1.4665200000000005, 1.4998500000000006, 1.5331800000000007, 1.8331500000000014, 1.8998100000000016, 2.0331300000000017, 2.2997700000000005, 2.39976, 2.43309, 2.46642, 2.4997499999999997, 2.5997399999999993, 2.7997199999999984, 2.8330499999999983, 2.899709999999998, 2.933039999999998, 2.9663699999999977, 3.0330299999999975, 3.332999999999996, 3.366329999999996, 3.399659999999996]]

# %%
i = 0

# Reset the simulation time
t = 0
dt = 1e-3
rsttime = 0.5
    
left['gamma'] = 0
right['gamma'] = 0

for iterations in range(1): # Training iterations

    t = 0
    
    tv = []
    u1 = []
    u2 = []

    t_spike = []
    n_spike = []
    
    # Start time
    t0 = t
    
    # Spike counts of e1 and e2
    left_count = 0
    right_count = 0
    
    
    # Sample a different digit every second iteration
    stimuli = []
    if iterations % 2 == 0:
        stimuli = test_data_right
        #stimuli = next(right_iter)
        ##############################################################################
        # INSERT SUPERVISION SIGNAL HERE, INHIBIT ONE OF THE TWO STDP NEURONS
        left['w_syn'][nr_of_neurons-1] = 0
        right['w_syn'][nr_of_neurons-1] = 0
        ##############################################################################
    else:
        #stimuli = next(left_iter)
        ##############################################################################
        # INSERT SUPERVISION SIGNAL HERE, INHIBIT ONE OF THE TWO STDP NEURONS
        left['w_syn'][nr_of_neurons-1] = 0
        right['w_syn'][nr_of_neurons-1] = 0
        ##############################################################################
    
    for neuron in list(range(0,nr_of_neurons)):
        l1 = spike_generator(stimuli[neuron])
        neurons[neuron] = l1
    
    simtime = spike_input_time(stimuli)
    
    # Simulate the network
    while t < t0+simtime:
        
        # Update network, including STDP
        spikes = update(dt, t, neurons, connections)
        
        # Store membrane potentials of n1 and n2 for plotting/analysis
        tv.append(t)
        u1.append(left['u'])
        u2.append(right['u'])
        
        # Store spikes needed for plotting/analysis
        if len(spikes)>0:
            for s in spikes:
                t_spike.append(t)
                n_spike.append(s)
        
        # Count number of spikes from e1 and e2
        left_count += spikes.count(left_index)
        right_count += spikes.count(right_index)
        
        # Timestep completed
        t += dt
        print('\r t = {}s, simtime = {}, iteration = {}'.format(str(t), str(simtime), str(i)), end='')

    i += 1
    
    # Let neurons and synapses rest before the next stimuli 
    
    while t < t0+simtime+rsttime:
        spikes = update(dt, t, neurons, connections)
        left_count += spikes.count(left_index)
        right_count += spikes.count(right_index)
        t += dt
        print('\r t = {}s, simtime = {}, iteration = {}, rest'.format(str(t), str(simtime), str(i)), end='')
    
    print('\n -----')
    print(left_count, right_count)
    
    plt.rcParams['figure.figsize'] = [10, 10]
    fig,(ax1,ax2,ax3) = plt.subplots(3,1, sharex=True)
    ax1.plot(tv,u1); ax1.set_ylabel('u1(t)')
    ax2.plot(tv,u2); ax2.set_ylabel('u2(t)')
    rasterplot(ax3, t_spike, n_spike,'Time [s]','Neuron index')
    
    plt.show()
# Out:
#  t = 3.8999999999996815s, simtime = 3.399659999999996, iteration = 1, rest
#  -----
# 96 108
